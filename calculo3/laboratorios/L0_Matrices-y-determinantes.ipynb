# %% [markdown]
# # Matrices y determinantes
#
# Laboratorio de cálculo diferencial e integral 2.
#
# Prof. Armando Benjamin Cruz Hinojosa (Gory).

# %%
import numpy as np
from PIL import Image as Im

# %% [markdown]
# ## Definición

# %% [markdown]
# Una *matriz* de $m\times n$ con valores en un campo $\mathbb{F}$, es una función $M: [n]\times[m] \rightarrow \mathbb{F}$ que representa un arreglo bidimesnional
#
# $$
# \left[
#     \begin{matrix}
#     M_{0,0} & M_{0,1} & \cdots & M_{0,n}\\
#     M_{1,0} & M_{1,1} & \cdots & M_{1,n}\\
#     \vdots & \vdots & \ddots & \vdots\\
#     M_{m,0} & M_{m,1} & \cdots & M_{m,n}\\
#     \end{matrix}
# \right]
# $$
#
# Donde cada $M_{i,j} := M(i,j)$ pertenece al campo $\mathbb{F}$

# %% [markdown]
# ### Estructuras de datos

# %%
# Lista de m listas de n elementos cada una

matriz = [
    [1,2,3],
    [4,5,6]
]

print('matriz:', matriz)
print('Typo de dato:', type(matriz))
print('m:', len(matriz))
print('n:', len(matriz[0]))
print('M[1][2]:', matriz[1][2])
# Out:
# matriz: [[1, 2, 3], [4, 5, 6]]
# Typo de dato: <class 'list'>
# m: 2
# n: 3
# M[1][2]: 6

# %%
# Arreglo de numpy
matriz = np.array([
    [1,2,3],
    [4,5,6]
], dtype=float)

print('matriz:', matriz)
print('Typo de dato:', type(matriz))
print('forma:', matriz.shape)
print('m:', len(matriz), matriz.shape[0])
print('n:', len(matriz[0]), matriz.shape[1])
print('M[1][2]:', matriz[1][2], matriz[1,2])
# Out:
# matriz: [[1. 2. 3.]
#  [4. 5. 6.]]
# Typo de dato: <class 'numpy.ndarray'>
# forma: (2, 3)
# m: 2 2
# n: 3 3
# M[1][2]: 6.0 6.0

# %%
# A partir de la función
def M(i,j):
    return 2*i + 3*j

np.fromfunction(M,(4,4))
# Out:
# array([[ 0.,  3.,  6.,  9.],
#        [ 2.,  5.,  8., 11.],
#        [ 4.,  7., 10., 13.],
#        [ 6.,  9., 12., 15.]])

# %% [markdown]
# ### Las pantallas son matrices

# %% [markdown]
# Las pantallas OLED son arreglos bidimensionales de OLEDs que se iluminan de forma específica para mostrar imágenes y videos. Esto hace a las matrices estructuras idoneas para almacenar información gráfica, como lo hacen por ejemplo los archivos PNG.

# %%
skull = Im.open('./Andy-Warhol-Skull-1976.png').convert("L")
skull
# Out:
# <PIL.Image.Image image mode=L size=480x430 at 0x7F4641D09DB0>

# %%
skull_array = np.asarray(skull)

print('forma:', skull_array.shape)
print('skull[50][50][R]:', skull_array[50,60])
# Out:
# forma: (430, 480)
# skull[50][50][R]: 87

# %% [markdown]
# ## Operaciones en matrices

# %% [markdown]
# ### Transposición

# %% [markdown]
# ### ¿Qué es el determinante?

# %% [markdown]
# El determinante es una función sobre el espacio de matrices.

# %% [markdown]
# ### Código para el cálculo

# %% [markdown]
# ## Sistemas de ecuaciones lineales

# %% [markdown]
# ## Proyecciones lineales

# %% [markdown]
# El cálculo lo estudiamos por dimensiones

# %% [markdown]
# Ejercicio del cono

# %%
# Interfaz
# Render cono y plano
# Dos graficas

# %% [markdown]
# ## Ejercicios

# %% [markdown]
# 1. Matriz de fibonacci
